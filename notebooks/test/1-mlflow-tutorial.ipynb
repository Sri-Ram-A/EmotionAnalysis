# %%
# ! pip install pynvml

# %%
import mlflow
import mlflow.tensorflow
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
NOTEBOOK_DIR  = Path().resolve()
BASE_DIR = NOTEBOOK_DIR.parents[0]
DATASET_DIR = BASE_DIR /  "data" / 'Twitter' / "preprocessed"
DATASET_FILE_PATH = DATASET_DIR  / 'train.csv'
DATASET_FILE_PATH.exists()
print("Project base dir is :",BASE_DIR)
# mlflow.enable_system_metrics_logging()
# Out:
# 2025-11-30 01:40:34.459280: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Project base dir is : /home/srirama/sr_proj/EmotionAnalysis

# %%
mlflow.set_tracking_uri(f"http://localhost:5000")

# %%
import numpy as np
import pandas as pd
df = pd.read_csv(DATASET_FILE_PATH,usecols=["sentiment","cleaned_text"],nrows=100)
df["cleaned_text"] = df["cleaned_text"].astype(str)
print("Null values",df.isnull().sum())
print("Shape of df :",df.shape)
# Out:
# Null values sentiment       0
# cleaned_text    0
# dtype: int64
# Shape of df : (100, 2)

# %%
mlflow.set_experiment("0-EXPLORE")
# Out:
# 2025/11/30 01:43:35 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/11/30 01:43:35 INFO mlflow.store.db.utils: Updating database tables
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# 2025-11-30 01:43:35 INFO  [89d4b8295536_create_latest_metrics_table_py] Migration complete!
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade 89d4b8295536 -> 2b4d017a5e9b, add model registry tables to db
# 2025-11-30 01:43:35 INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Adding registered_models and model_versions tables to database.
# 2025-11-30 01:43:35 INFO  [2b4d017a5e9b_add_model_registry_tables_to_db_py] Migration complete!
# 2025-11-30 01:43:35 INFO  [alembic.runtime.migration] Running upgrade 2b4d017a5e9b -> cfd24bdc0731, Update run status constraint with killed
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade cfd24bdc0731 -> 0a8213491aaa, drop_duplicate_killed_constraint
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 0a8213491aaa -> 728d730b5ebd, add registered model tags table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 728d730b5ebd -> 27a6a02d2cf1, add model version tags table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 27a6a02d2cf1 -> 84291f40a231, add run_link to model_version
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 84291f40a231 -> a8c4a736bde6, allow nulls for run_id
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade a8c4a736bde6 -> 39d1c3be5f05, add_is_nan_constraint_for_metrics_tables_if_necessary
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 39d1c3be5f05 -> c48cb773bb87, reset_default_value_for_is_nan_in_metrics_table_for_mysql
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade c48cb773bb87 -> bd07f7e963c5, create index on run_uuid
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade bd07f7e963c5 -> 0c779009ac13, add deleted_time field to runs table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 0c779009ac13 -> cc1f77228345, change param value length to 500
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade cc1f77228345 -> 97727af70f4d, Add creation_time and last_update_time to experiments table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 97727af70f4d -> 3500859a5d39, Add Model Aliases table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 7f2a7d5fae7d -> 2d6e25af4d3e, increase max param val length from 500 to 8000
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 2d6e25af4d3e -> acf3f17fdcc7, add storage location field to model versions
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade acf3f17fdcc7 -> 867495a8f9d4, add trace tables
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 867495a8f9d4 -> 5b0e9adcef9c, add cascade deletion to trace tables foreign keys
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 5b0e9adcef9c -> 4465047574b1, increase max dataset schema size
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 4465047574b1 -> f5a4f2784254, increase run tag value limit to 8000
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade f5a4f2784254 -> 0584bdc529eb, add cascading deletion to datasets from experiments
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 0584bdc529eb -> 400f98739977, add logged model tables
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 400f98739977 -> 6953534de441, add step to inputs table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 6953534de441 -> bda7b8c39065, increase_model_version_tag_value_limit
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade bda7b8c39065 -> cbc13b556ace, add V3 trace schema columns
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade cbc13b556ace -> 770bee3ae1dd, add assessments table
# 2025-11-30 01:43:36 INFO  [alembic.runtime.migration] Running upgrade 770bee3ae1dd -> a1b2c3d4e5f6, add spans table
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Running upgrade a1b2c3d4e5f6 -> de4033877273, create entity_associations table
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Running upgrade de4033877273 -> 1a0cddfcaa16, Add webhooks and webhook_events tables
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Running upgrade 1a0cddfcaa16 -> 534353b11cbc, add scorer tables
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Running upgrade 534353b11cbc -> 71994744cf8e, add evaluation datasets
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Running upgrade 71994744cf8e -> 3da73c924c2f, add outputs to dataset record
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Running upgrade 3da73c924c2f -> bf29a5ff90ea, add jobs table
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# 2025-11-30 01:43:37 INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2025/11/30 01:43:37 INFO mlflow.tracking.fluent: Experiment with name '0-EXPLORE' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/srirama/sr_proj/EmotionAnalysis/test/mlruns/1', creation_time=1764467017590, experiment_id='1', last_update_time=1764467017590, lifecycle_stage='active', name='0-EXPLORE', tags={}>

# %%
# Print connection information
print(f"MLflow Tracking URI: {mlflow.get_tracking_uri()}")
print(f"Active Experiment: {mlflow.get_experiment_by_name('0-EXPLORE')}")
# Out:
# MLflow Tracking URI: http://localhost:5000
# Active Experiment: <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1763300068023, experiment_id='1', last_update_time=1763300068023, lifecycle_stage='active', name='0-EXPLORE', tags={}>

# %%
run =  mlflow.start_run(run_name="Learning")
# Out:
# 2025/11/16 13:34:28 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.

# %%
# in UI- logged under Evaluation
mlflow.log_table(df.sample(50), artifact_file="artifact/table.json")

# %%
import psutil, time, mlflow
# in UI - Logged under Chart and Table/x/Metrics/- 
for i in range(30):
    mlflow.log_metric("cpu_percent", psutil.cpu_percent())
    mlflow.log_metric("ram_percent", psutil.virtual_memory().percent)
    time.sleep(0.5)

# %%
#  In UI - Logged under Table/x/Tags
mlflow.set_tag("description", "Baseline model with CountVectorizer + LR")
mlflow.set_tag("dataset", "cleaned_text_v1")
mlflow.set_tag("experiment_stage", "baseline")

# %%
#  In UI - Logged under Table/x/Parameter
mlflow.log_params({
    "vectorizer": "CountVectorizer",
    "vocab_size": 100,
    "model": "LogisticRegression",
    "C": 1.0,
    "max_iter": 1000
})

# %%
mlflow.end_run()
# Out:
# 2025/11/16 13:36:04 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/11/16 13:36:04 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# 🏃 View run Learning at: http://localhost:5000/#/experiments/1/runs/e84457bca61046f69e31e3edb2352b3c
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
